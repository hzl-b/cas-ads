# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt

# %%
# Dataset
data = {'Before_Weight' : [70, 80, 76, 65, 70, 70, 63, 78, 80, 92, 62, 82, 110, 90, 61, 66, 70, 82, 63, 90],
    'After_Weight' : [64, 75, 76, 66, 61, 67, 62, 74, 70, 82, 62, 85, 90, 82, 60, 62, 75, 75, 59, 81]}

# Create a DataFrame from the dictionary
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#     Before_Weight  After_Weight
# 0              70            64
# 1              80            75
# 2              76            76
# 3              65            66
# 4              70            61
# 5              70            67
# 6              63            62
# 7              78            74
# 8              80            70
# 9              92            82
# 10             62            62
# 11             82            85
# 12            110            90
# 13             90            82
# 14             61            60
# 15             66            62
# 16             70            75
# 17             82            75
# 18             63            59
# 19             90            81

# %%
# Calculate the difference between Before_Weight and After_Weight
df['Weight_Difference'] = df['Before_Weight'] - df['After_Weight']

# Generate the QQ plot
stats.probplot(df['Weight_Difference'], dist="norm", plot=plt)
plt.title('QQ Plot of Weight Differences')
plt.show()

# %%
# Perform the D'Agostino-Pearson test for Weight_Difference
stat_before, p_value_before = normaltest(df['Weight_Difference'])
alpha = 0.05
print('Alpha = ',alpha)
print('p_value_before = ', p_value_before)
# Interpretation
if p_value_before > alpha:
    print("The null hypothesis cannot be rejected (data is normally distributed).")
else:
    print("The null hypothesis can be rejected (data is not normally distributed).")
# Out:
# Alpha =  0.05
# p_value_before =  0.09628584666315106
# The null hypothesis cannot be rejected (data is normally distributed).

# %%
# Perform the paired t-test
stats.ttest_rel(df['Before_Weight'], df['After_Weight'])
# Out:
# TtestResult(statistic=3.640213399323864, pvalue=0.0017415183697449214, df=19)
